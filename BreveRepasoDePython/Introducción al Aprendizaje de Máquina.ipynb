# %% [markdown]
# # **INTRODUCCIÓN AL APRENDIZAJE DE MÁQUINA**
#
# Panorama general de cómo trabajan los modelos de aprendizaje y cómo se usan. </p>
# Un amigo suyo ha ganado varios millones especulando en la venta de casas, y le ofrece asociarse por su interés en data science. El pone el dinero y usted el modelo para predecir cuánto deben costar las casas. <p>
# Usted le pregunta a su amigo cómo lo ha realizado hasta ahorita, y le contesta que por "intuición". Usted continua preguntando e identifica que hay ciertos patrones. <p>
# El aprendizaje de máquina trabaja en la misma forma. Iniciaremos con un modelo llamado **Árbol de Decisión** que son fáciles de entender y son la base de otros modelos. <p>
# Por ejemplo:

# %% [markdown]
# ![Untitled (7).png](data:image/png;base64,...)

# %% [markdown]
# Por el momento no consideremos cómo se construye un árbol de decisión. Lo importante aquí es mencionar que los datos permiten dividir las casas en dos grupos. El primer paso es capturar los patrones de los datos llamado entrenamento (**fitting or trainng**) del modelo.<p>
# Una vez que se entrena el modelo, se usan nuevos datos para **predecir** el comportamiento de nuevos casos.<p>

# %% [markdown]
# #Mejorar el árbol de decisión
#
# ¿Dados dos árboles cuál es mejor?
#
# ![Untitled (9).png](data:image/png;base64,...)

# %% [markdown]
# Un árbol puede considerar más características o "divisiones" lo que lo hace más profundo.
#
# ![Untitled (10).png](data:image/png;base64,...)

# %% [markdown]
# #**Tipos de Aprendizaje de Máquina**

# %% [markdown]
# ##**3 Tipos de ML**
#
# > Aprendizaje supervisado:
#
# *   Datos etiquetados
# *   Retroalimentación directa
# *   Predicción Salida/Características
#
# > Aprendizaje no supervidado
#
# *   No hay etiquetas
# *   No hay retroalimentación
# *   Se encuentra la estructura escondida en los datos
#
# > Aprendizaje por refuerzo
#
# *   Proceso de decisión
# *   Sistema de recompensas
# *   Se aprenden series de acciones

# %% [markdown]
# ##**Predicciones con aprendizaje supervisado**
#
# La meta principal es aprender un modelo de datos de entrenamiento clasificados (etiquetas) que permiten hacer predicciones sobre datos no vistos o futuros.
#
# Supervisado se refiere a un conjunto de ejemplos donde la salida deseada (etiquetas) se conocen.
#
# La ***clasificación*** es una subcategoría del aprendizaje supervisado donde la meta es predecir la clase de una nueva instancia, basada en observaciones pasadas.
#
# Ejemplos:
# * Spam: clasificación binaria
# * Reconocimiento de caracteres escritos: clasificación múlticlase

# %% [markdown]
# Clasificación binaria, 30 ejemplos, 2 dimensiones
#
# ![ClasificaciónBinaria.png](data:image/png;base64,...)

# %% [markdown]
# #**Clasificación binaria**
#
# La clasificación es uno de los problemas de ML más comunes, ejemplos:
#
# > cliente va a comprar o no
# > transacción fraudullenta
# > señales en el espacio son evidencia de un nuevo planeta
# > prueba médica evidencia de una enfermedad
#
# En los datos, las clases pueden estar representadas por una cadena como "Si" o "No", o "Perro" y "Gato". Antes de usar los datos deben asignarse las etiquetas de la clase: una clase 0 y la otra 1. Asignar etiquetas numéricas permite que una ANN pueda usarse.

# %% [markdown]
# ###**Regresión**
#
# Aprendizaje supervisado, predicción de salidas continuas. Se trata de encontrar la relación entre características y la salida. Ejemplo, calificaciones de alumnos.
#
# Dado un predictor X y una variable de salida y, ajustar la línea a los puntos que minimice la distancia entre los puntos y una línea ajustada. Después de puede predecir la variable de slaida para nuevos datos.

# %% [markdown]
# ![Regresión.png](data:image/png;base64,...)

# %% [markdown]
# ##**Aprendizaje no supervisado**
#
# En el aprendizaje supervisado se conoce la respuesta antes del entrenamiento, en el aprendizaje no supervisado, sin embargo, se trabaja con datos no etiquetados o que se desconoce su estructura. Se explora la estructura de los datos y se extrae información significativa sin guía o conocimiento.
#
# El ***clustering*** es una técnica exploratoria que permite organizar información en subgrupos (clusters) sin tener conocimiento previo de la pertenencia.
#
# Cada cluster que se origina durante el análisis define un grupo de objetos que comparten cierto grado de similaridad y son diferentes a elementos de otros clusters. Ejemplo, vendedores descubren grupos de clientes con base en sus intereses.

# %% [markdown]
# ##Accuracy y Cross-Entropy
#
# El ***accuracy*** es una de varias métricas que se usan para medir el éxito de un problema de clasificación. Es la relación entre las predicciones correctas y el total de predicciones: `accuracy = númeroCorrecto / total`.  Un modelo que siempre predice correctamente debería tener un accuracy de `1.0`. Se usa cuando las clases en el dataset ocurren con igual frecuencia.
#
# El accuracy y la mayoría de las métricas de clasificación no pueden usarse como función loss, ya que la SGD necesita que los cambios sean suaves, pero el accurancy cambia bruscamente. El substituto es la función *cross-entropy*.
#
# Recordemos que la función loss define el objetivo de la ANN durante el entrenamiento cuando la meta era minimizar la distancia entre la salida esperada y la salida predecida. Esta distancia se media con MAE.
#
# En la clasificación, se requiere de una distancia entre *probabilidades*. **Croos-entropy** mide la distancia entre dos distribuciones de probabilidad.
#
# La idea es que la red prediga la clase correcta con una probabilidad de 1.0. Mientras más lejos del 1.0 sea la probabilidad, mayor será el cross-entropy

# %% [markdown]
# ![PredictedProb.png](data:image/png;base64,...)

# %% [markdown]
# ##**Probabilidades con la función sigmoide**
#
# El accuracy y la cross-entropy requieren probabilidades como entrada, es decir números entre 0 y 1. Para convertir las salidas producidas por una capa densa en probabilidadess, se agrega una nueva clase de función de activación, la **activación sigmoide**, que mapea números reales en el intervalo [0,1].
#
# Para obtener la clase de predicción final, se define una probablidad
# *threshold* (umbral). Por lo general es 0.5, que por redondeo nos dará la clase correcta: menos de 0.5 significa que la clase tendrá etiqueta 0 y más de .5, que la clase tendrá etiqueta 1. Keras usa 0.5 por default.

# %% [markdown]
# ![Sigmoide.png](data:image/png;base64,...)
#
# La función sigmoide mapea números reales en el intervalo [0,1]

# %% [markdown]
# ##**Usar pandas para familiarizarse con los datos**
#
# El primer paso en cualquier proyecto de machine learning es familiarizarse con los datos. Pandas es una librería que permite esto y es de las más usadas para explorar y manipular los datos.<p>
# La mayoría lo abrevia como **pd**. Así:
#
#
# ```
# import pandas as pd
# ```
# Un concepto importante de esta librería es el "DataFrame", que puede pensarse como una tabla, una página de Excel, una tabla en SQL. <p>
# Un ejemplo son los datos de Melbourne housing

# %%
import pandas as pd
a= "https://www.kaggle.com/elikplim/ecoli-data-set?select=ecoli.csv"
df1 = pd.read_csv(a)
df1.describe ()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-c3673d0e5821> in <module>()
#       1 import pandas as pd
#       2 a= "https://www.kaggle.com/elikplim/ecoli-data-set?select=ecoli.csv"
# ----> 3 df1 = pd.read_csv(a)
#       4 df1.describe ()
#
# ...

# %%
import pandas as pd
a = "https://raw.githubusercontent.com/mudgalvivek2911/VIVEK_Kaggle/f009482b3f22a151b86b098fbd6ad07f1bb7ac2a/Melbourne_housing_FULL.csv"
df1 = pd.read_csv(a)
df1.describe ()
# Out:
#               Rooms         Price  ...    Longtitude  Propertycount
# count  34857.000000  2.724700e+04  ...  26881.000000   34854.000000
# mean       3.031012  1.050173e+06  ...    145.001851    7572.888306
# std        0.969933  6.414671e+05  ...      0.120169    4428.090313
# min        1.000000  8.500000e+04  ...    144.423790      83.000000
# 25%        2.000000  6.350000e+05  ...    144.933500    4385.000000
# 50%        3.000000  8.700000e+05  ...    145.007800    6763.000000
# 75%        4.000000  1.295000e+06  ...    145.071900   10412.000000
# max       16.000000  1.120000e+07  ...    145.526350   21650.000000
#
# [8 rows x 13 columns]

# %% [markdown]
# ##Interpretación de los datos en la descripción
#
# El primer renglón, **count**, muestra cuántos renglones no tienen valores faltantes (non-missing). Los valores faltantes pueden tener muchas causas. El segundo valor, **mean**, es el promedio. Después **std** es la desviación estándar. También se muestran el valor mínimo, el máximo y los percentiles. Por ejemplo, en 25%, está el número que es mayor al 25% de los valores y menor al 75%.

# %% [markdown]
# #Seleccionar los datos del modelo
#
# Por lo general existen muchos datos o simplemente se desean graficar de una manera más sencilla, por lo cual normalmente se seleccionan algunas variables, normalmente por intuición o a través de técnicas estadísticas.

# %%
df1.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# Existen datos faltantes, por el momento eliminaremos las casas que los tienen

# %%
df1 = df1.dropna(axis=0)

# %% [markdown]
# Por convención, el objetivo de predicción es **y**, en este caso será el precio.

# %%
y = df1.Price

# %% [markdown]
# Selección de características
#
# Las columnas son las entradas del modelo (después se usan para hacer predicciones) y son llamadas **características**. Por convención son llamadas **X**.

# %%
características = ['Rooms', 'Bathroom', 'Landsize', "Longtitude"]
X = df1[características]

# %% [markdown]
# Revisemos los datos que se usarán para predecir los precios de las casas.

# %%
X.describe ()
# Out:
#              Rooms     Bathroom      Landsize   Longtitude
# count  8887.000000  8887.000000   8887.000000  8887.000000
# mean      3.098909     1.646450    523.480365   144.991393
# std       0.963786     0.721611   1061.324228     0.118919
# min       1.000000     1.000000      0.000000   144.423790
# 25%       2.000000     1.000000    212.000000   144.920000
# 50%       3.000000     2.000000    478.000000   144.998500
# 75%       4.000000     2.000000    652.000000   145.064560
# max      12.000000     9.000000  42800.000000   145.526350

# %%
X.head ()
# Out:
#     Rooms  Bathroom  Landsize  Longtitude
# 2       2       1.0     156.0    144.9934
# 4       3       2.0     134.0    144.9944
# 6       4       1.0     120.0    144.9941
# 11      3       2.0     245.0    144.9993
# 14      2       1.0     256.0    144.9954
