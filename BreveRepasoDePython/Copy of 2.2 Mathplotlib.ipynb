# %% [markdown]
# #**MATHPLOTLIB**

# %% [markdown]
# **Matplotlib Pyplot**
#
# <p>La mayoría de las funciones están en el submódulo pyplot </p>
# <p>Por ejemplo: plot () dibuja una línea de puntos, el primer parámetro contine las coordenadas en x y el segundo las de y.</p>
# <p>Documentación en: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html</p>
# <p><b>Ejemplo: </b></p>
# <p>Para graficar los puntos (0,0), (2,4) y (4,8) se tendrían como parámetros de la función plot [0,2,4] y [0,4,8]</p>

# %%
pip install simple-colors

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create some mock data
t = np.arange(0.01, 10.0, 0.01)
data1 = np.exp(t)
data2 = np.sin(2 * np.pi * t)




fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from simple_colors import *


path1= "/content/drive/MyDrive/CursoPythonAvanzado/BreveRepasoDePython/Datasets/HistoryWithoutER.xlsx"
path2= "/content/drive/MyDrive/CursoPythonAvanzado/BreveRepasoDePython/Datasets/HistoryWithER.xlsx"

df_WOER = pd.read_excel(path1)
df_WER = pd.read_excel(path2)

print("\n                  REGULAR \n\n",df_WOER,"\n")
print("\n              EMOTION REGULATION \n\n", df_WER)

events = df_WER["   EVENT    "]

ax.xaxis.set_tick_params(labelsize=20)
plt.rcParams["figure.figsize"] = (10, 6)
plt.title ('Emotional Regulation');
plt.plot(df_WER["MOOD     "], marker="o",label='Emotion Regulation')
plt.plot(df_WOER["MOOD     "],'o--', label='Normal')
plt.xticks(rotation=15)
s = x.str.upper()

plt.xticks(np.arange(len(events)), events+'\n\n'+s)
plt.legend(bbox_to_anchor=(1, 1), loc=3)
#plt.legend(loc='best')
plt.xlabel("Events")
plt.ylabel("Mood value")
plt.grid()
plt.savefig("Ejemplo1.jpg")
plt.show()







x = df_WOER["EMOTION  "]
y = df_WOER["INTENSITY"]
y2 = df_WER["INTENSITY"]
numero_de_grupos = len(df_WOER["EMOTION  "])
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.3
plt.bar(indice_barras, y2, width=ancho_barras, label='Emotion Regulation')
plt.bar(indice_barras + ancho_barras, y, width=ancho_barras, label='Normal')
plt.legend(loc='best')
plt.xticks(indice_barras + ancho_barras, x)
plt.xticks(rotation=15)

plt.ylabel('Intensity')
plt.xlabel('Emotion')
plt.savefig("Ejemplo2.jpg")
plt.show()
# Out:
#                   REGULAR
#
#     MOOD      EMOTION    INTENSITY     EVENT
# 0  -1.482771  Distress   4.774208         Enter
# 1  -1.182481      Love   0.912035         Hello
# 2   0.000000      Love   2.334832  Conversation
# 3   1.453116      Love   4.678724           Hug
# 4   0.000000  Distress   4.357960    Discussion
# 5   0.593108       Joy   1.909683       Congrat
# 6  -1.436817  Distress   6.513994           Bye
# 7  -3.001257      Hate   5.090304         Fired
# 8  -5.102087      Hate   6.875219         Crash
# 9  -3.124964       Joy   6.177227       Profits
#
#
#               EMOTION REGULATION
#
#     MOOD      EMOTION    INTENSITY     EVENT      APPLIED STRATEGY
# 0  -1.023074  Distress   3.294082         Enter  Attention Deployment
# 1  -0.687166      Love   1.043716         Hello                   Any
# 2   0.000000      Love   2.476716  Conversation                   Any
# 3   1.453116      Love   4.678724           Hug                   Any
# ...

# %%
print('\033[1m' + 'Your Name' + '\033[0m')
# Out:
# Your Name

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np

xPuntos = np.array ([0,2,4])
yPuntos = np.array ([0,4,8])

plt.plot (xPuntos,yPuntos)

# %% [markdown]
# <p>Una forma de llamar al método es: plot([x], y, [fmt])</p>
# <p>fmt, es un string opcional. Por ejemplo 'or' utilizará círculos rojos</p>
# <p>fmt = '[marker][line][color]'</p>
# <p></p>

# %%
plt.plot (xPuntos,yPuntos, 'r')

# %%
plt.plot (xPuntos,yPuntos, 'og')

# %%
plt.plot (xPuntos,yPuntos, 'D:m')

# %% [markdown]
# Coordenada x opcional

# %%
yOtrosPuntos = np.array ([4,8,2,10,1,14, 5])
plt.plot (yOtrosPuntos, '+--c')

# %%
#Tamaño del marker
plt.plot (xPuntos,yPuntos, 's-.k', ms = 50)

# %%
#Contorno del marker
plt.plot (yOtrosPuntos, 's--c', ms = 15, mec= 'k')

# %%
#Ancho de la línea
plt.plot (xPuntos,yPuntos, linewidth = 10)

# %%
#Múltiples líneas
y1 = np.array ([2,4,6,8,10])
y2 = np.array ([1,2,4,8,16])
y3 = np.array ([0,1,8,16,32])
plt.plot (y1)
plt.plot (y2)
plt.plot (y3)

# %%
#Etiquetas
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Pulso promedio")
plt.ylabel("Calorias quemadas")

plt.show()

# %%
#Título
plt.plot(x, y)
plt.title ("Datos de entrenamiento")
plt.xlabel("Pulso promedio")
plt.ylabel("Calorias quemadas")
# Out:
# Text(0, 0.5, 'Calorias quemadas')

# %%
#Fuente 
font1 = {'family':'serif','color':'red','size':10}
font2 = {'family':'serif','color':'darkred','size':12}

plt.title("Datos de entrenamiento", fontdict = font1)
plt.xlabel("Pulso promedio", fontdict = font2)
plt.ylabel("Calorias quemadas", fontdict = font2)

plt.plot(x, y)

# %%
#Posición del título
plt.title("Datos de entrenamiento", fontdict = font1, loc = 'right')
plt.xlabel("Pulso promedio", fontdict = font2)
plt.ylabel("Calorias quemadas", fontdict = font2)

plt.plot(x, y)

# %%
#Ejercicio: Cambiar el título a la izquierda (left) de la gráfica anterior

# %% [markdown]
# ##Ejercicio
#
# Hacer una gráfica lo más parecido a la siguiente

# %% [markdown]
# ![senoCoseno.png](data:image/png;base64,...)

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %% [markdown]
# Fondo de la gráfica

# %%
#Etiquetas
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title ("Datos de entrenamiento")
plt.xlabel("Pulso promedio")
plt.ylabel("Calorias quemadas")

plt.grid ()

# %%
plt.plot(x, y)
plt.title ("Datos de entrenamiento")
plt.xlabel("Pulso promedio")
plt.ylabel("Calorias quemadas")

#Definición de las líneas a mostrar
plt.grid (axis = 'y')

# %%
#Ejercicio, cambiar las líneas del grid  a axis = 'x'
#para que aparezca la gráfica anterior

plt.plot(x, y)
plt.title ("Datos de entrenamiento")
plt.xlabel("Pulso promedio")
plt.ylabel("Calorias quemadas")

plt.grid (axis = 'x')

# %%
#Otras propiedades del grid
plt.plot(x, y)
plt.title ("Datos de entrenamiento")
plt.xlabel("Pulso promedio")
plt.ylabel("Calorias quemadas")

plt.grid(color = 'red', linestyle = '--', linewidth  = 3.5)

# %% [markdown]
# *Ejercicio:* Cambiar la gráfica anterior para que el grid
# y el color de la línea tengan su combinación favorita

# %% [markdown]
# ##**Subplots**
#
# Varios plots en una figura

# %%
#plot 1
y = np.array ([5,10,15,10])
plt.subplot (1,2,1) #(nrenglones, ncolulmnas, índice)
plt.plot (y)

#plot 2
y = np.array ([2,4,6,8,10])
plt.subplot (1,2,2)
plt.plot (y)

# %%
#plot 1
y = np.array ([5,10,15,10])
plt.subplot (2,1,1) #(nrenglones, ncolulmnas, índice)
plt.plot (y)

#plot 2
y = np.array ([2,4,6,8,10])
plt.subplot (2,1,2)
plt.plot (y)

# %% [markdown]
# ##**Otros tipos de gráficas**

# %%
#Scatter
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)

# %%
#Dos series en la misma figura
#día 1
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#día 2
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

# %%
#día 1
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

#día 2
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#10f909')

# %%
#De colores y tamaños
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colores = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
tamaños = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, c=colores, s = tamaños)

# %% [markdown]
# *Ejercicio:* ¿Qué sucede si el número de colores es menor que el número de datos?
#
# ¿Cómo podría dibujarse la gráfica anterior con sólo 3 colores de puntos?

# %%
colores = np.array(["red","green","blue"])
plt.scatter(x, y, c=colores)

# %%
#100 puntos aleatorios de colores, tamaños y colorbar ()
x = np.random.randint(100, size=(100)) #100 números entre 1 y 99
y = np.random.randint(100, size=(100))
colores = np.random.randint(100, size=(100))
tamaños = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colores, s=tamaños, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

# %% [markdown]
# ###Barras

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
#Barras horizontales
frutas = ['uvas', 'manzanas', 'peras']
cantidad = [400, 300, 350]
plt.barh (frutas, cantidad)
# Out:
# <BarContainer object of 3 artists>

# %%
#Color de las barras
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

#plt.bar(x,y, color = "red")
#plt.bar(x,y, color = (0.1, 0.2, 0.5)) #En RGB
#plt.bar(x,y, color = (0.1, 0.2, 0.5, 0.3 )) #En RGBA alfa es el factor de transparencia
#plt.bar(x,y, color = '#0f0f0f') #hexadecimal
#plt.bar(x,y, color = 'c' ) #short hand
plt.bar(x,y, color = 'aquamarine') #xkcd color survery case-insensitive
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Colores más comunes xkcd en https://xkcd.com/color/rgb/

# %%
#ancho de las barras
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y, color = "hotpink", width=0.1)
# Out:
# <BarContainer object of 4 artists>

# %%
frutas = ['uvas', 'manzanas', 'peras']
cantidad = [400, 300, 350]
plt.barh (frutas, cantidad, color ='#4C5C6C', height=0.7)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ###Histogramas
#
# Muestra la frecuencia de las distribuciones.
#
# Ver: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %%
#Generación de una distribución normal
h = np.random.normal (100,10,100) #loc, escala, tamaño
print (h)
# Out:
# [ 92.14981647  91.43145888  89.53541835 100.28919876 104.08918257
#   84.29474531  88.87856761 106.23989692  96.14000773 101.87144381
#   89.79556425 110.08259336  97.96590515  95.68104259  88.37355589
#  110.81153811 107.68666618 104.27917904 113.58313956 110.48161235
#  102.72128884 103.97049425 121.76123981 118.30453556 104.53136983
#  109.47740862 111.03790708  76.71085344  94.26475449  94.88176056
#  100.62031782  95.1366775  126.4121307  106.81378478  88.87028937
#  105.36186486 109.45114145  80.89148336  96.71922782 106.79809981
#   83.92804677  95.60839687  90.29018619  81.13977322  92.01884073
#  109.10973588  85.80183174  92.56431342  97.95543563  94.95240536
#  118.5379866  117.75344051 115.34927853  97.6062004  108.92896716
#   98.69662263  87.26947899 113.16740727  95.84695777 103.24522084
#  105.72603214  79.0827524  100.31102217 123.62169952  93.69083256
#  111.88389237  90.10464008  88.63992918 100.60489851  95.27856471
# ...

# %%
plt.hist (h)
# Out:
# (array([ 5.,  4., 15., 16., 16., 15., 14.,  8.,  4.,  3.]),
#  array([ 76.71085344,  81.68098116,  86.65110889,  91.62123662,
#          96.59136434, 101.56149207, 106.53161979, 111.50174752,
#         116.47187524, 121.44200297, 126.4121307 ]),
#  <a list of 10 Patch objects>)

# %%
#Pie

y = np.array ([5,35,25,15])
plt.pie (y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe92a632a90>,
# ...
#  [Text(1.0788638084435536, 0.2145993542177411, ''),
#   Text(-0.21459935421774104, 1.0788638084435536, ''),
#   Text(-0.6111272563215624, -0.9146165735327998, ''),
#   Text(0.9146165735327998, -0.6111272563215624, '')])

# %%
#Etiquetas
etiquetas = ['kiwi','Manzana', 'uva', 'pera']
plt.pie (y, labels = etiquetas)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe92a584b10>,
# ...
#  [Text(1.0788638084435536, 0.2145993542177411, 'kiwi'),
#   Text(-0.21459935421774104, 1.0788638084435536, 'Manzana'),
#   Text(-0.6111272563215624, -0.9146165735327998, 'uva'),
#   Text(0.9146165735327998, -0.6111272563215624, 'pera')])

# %%
#Encabezado
plt.pie (y, labels = etiquetas)
plt.legend (title = "4 frutas:")

# %%
 
import numpy as np
import matplotlib.pyplot as plt

# Calcula las coordenadas x e y para las curvas de seno y coseno
x = np.arange(0, 5 * np.pi, 0.01)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Grafica los puntos
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Seno y coseno')
plt.legend(['Seno', 'Coseno'])
plt.show();

# %% [markdown]
# ##Ejercicio
#
# En equipos de 3 personas, abrir el archivo de vinos visto en numpy y hacer 3 gráficas que permitan entender la información que se presenta ahí.
