# %% [markdown]
# ##Ejercicio:
#
# Agregar a la clase Persona el dato miembro ocupación y adaptar el método constructor. También agregar el método esAlumno () que regresa un valor booleano

# %%
#Adaptar el siguiente código
class Persona:
  def __init__(self, nombre, edad, ocupación):
    self.nombre = nombre
    self.edad = edad
    #self.ocupación = ocupación.lower ()
    self.ocupación = ocupación

  def presentarse (self):
    print ("\nMi nombre es "+ self.nombre)
    print ("Mi edad es " + str (self.edad))
    print ("Mi ocupación es " + str (self.ocupación))

  def esAlumno (self):
    alumno = (self.ocupación == "alumno" or self.ocupación == "alumna")
    return alumno
    #(self.ocupación == "alumno" or self.ocupación == "alumna")

doctor = Persona ("Luis", 40, "doctor")
doctor.presentarse ()

alumna = Persona ("Ana", 20, "alumna")
alumna.presentarse ()    

print (alumna.esAlumno ())
print (doctor.esAlumno())
# Out:
# Mi nombre es Luis
# Mi edad es 40
# Mi ocupación es doctor
#
# Mi nombre es Ana
# Mi edad es 20
# Mi ocupación es alumna
# True
# False

# %% [markdown]
# ##Ejercicio
# <p>Crear un método establecerOcupación en la clase Persona que imprima "no tengo profesión :( "</p>

# %%
class Persona:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad

  def presentarse (self):
    print ("Mi nombre es "+ self.nombre)
    print ("Mi edad es " + str (self.edad)+" años")

# %%
class Trabajador(Persona): # Esta clase hereda de la clase de arriba
  def establecerOcupación(self):
    print("no tengo profesión :( ")

profe1 = Trabajador("Juan", 25)
profe1.presentarse()
profe1.establecerOcupación()
# Out:
# Mi nombre es Juan
# Mi edad es 25 años
# no tengo profesión :(

# %% [markdown]
# ##Ejercicio
# <p>La sobrecarga de este operador usa el método __contains__. Requiere un argumento extra que es el elemento que se busca. El método debe regresar un valor booleano. Modificar la clase Tweets para que soporte el operador in donde se verifique si cierta palabra está en el tweet

# %%
class Tweet:
  
    def __init__(self, mensaje, hora):
        self.mensaje = mensaje
        self.hora = hora
        
    def __lt__(self, otro):
        return self.hora < otro.hora
        
    def __gt__(self, otro):
        return self.hora > otro.hora   
    
    def __contains__(self, palabra):
        return palabra in self.mensaje

      #implementar el método
    

#Cree un tweet que incluya la palabra cereal

#Escriba el código necesario para buscar la palabra 'cereal' en ese tweet
#imprima si se encontró o no

#cree otro tweet donde no aparezca la palabra 'cereal' y busque si el tweet 
#la contiene

Palabra = "cereal" 
anteriorTweet = Tweet("Este es un tweet con cereal",20)
recienteTweet = Tweet("Este es un tweet reciente",1000)

print(Palabra in recienteTweet)
# Out:
# False
