# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

X = [1,2,3,4,4,6]
Y = [62,78,70,90,93,103]
#for j in range (1,100):
  # X.append(random.randint(j,j**2))
  # Y.append(random.randint(j-5,j+25))


#Y = X

X = np.array(X)
Y = np.array(Y)
n = len(X)

sumX = sum(X)
sumY = sum(Y)
sumX2 = sum(X*X)
sumY2 = sum(Y*Y)
sumXY = sum(X*Y)
promX = sumX/n
promY = sumY/n

m = (sumX*sumY - n*sumXY)/(sumX**2 - n*sumX2)
b = promY - m*promX

plt.plot(X,Y, 'o')
plt.plot(X,m*X+b)


sigmX = np.sqrt(sumX2/n - promX**2)
sigmY = np.sqrt(sumY2/n - promY**2)

sigmXY = sumXY/n - promX*promY
R2 = (sigmXY/(sigmX*sigmY))**2
print('Valor de m = ',m)
print('Valor de b = ',b)
print('Valor de R2 = ',R2)
# Out:
# Valor de m =  8.130434782608695
# Valor de b =  55.56521739130435
# Valor de R2 =  0.8565584813227167

# %%
import time
A = []
A = np.asfarray(A)

for j in range(n):
  A = (Y[j] - X[j]*m+b)
  a += A
  print(a)




#print(Y[14],m*X[14]+b)
#print(X,Y)
#plt.plot(X[0],m*X[0]+b,'o') 
#plt.plot(X[0],Y[0],'o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6dac0ec50e8d> in <module>()
#       5 for j in range(n):
#       6   A = (Y[j] - X[j]*m+b)
# ----> 7   a += A
#       8   print(a)
#       9
#
# NameError: name 'a' is not defined
