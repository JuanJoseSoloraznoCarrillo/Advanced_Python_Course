# %% [markdown]
# #Presentación
# ##Nombre: Juan José Solórzano Carrillo
# ###Edad: 29 años

# %% [markdown]
# ![JuanjO.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###Lista de comidas favoritas
#
# 1. Pescado.
# 2. Pechugas de pollo rellenas.
# 3. Chiles rellenos.
# 4. Café
#
# ###Lista de deportes favoritos
#
# * Automovilismo
# * Tiro con arco
# * Senderismo

# %% [markdown]
# ###Tabla
#
# |Género | Edad |
# |---|---|
# |Dama / Caballero | Años|
# |Dama | 24|
# |Caballero | 44|
# |Dama | 19|
# |Dama | 14|
# |Caballero | 18|

# %% [markdown]
# ###*Ecuación*
# $F = G  \frac{m_1*m_2}{d^2}$

# %% [markdown]
# ###Lista de tareas
#
# - [x] Hacer tarea mate
# - [ ] Hacer ejercicios Python avanzado
# - [X] Sacar a pasear al gato
# - [ ] Salir a correr

# %% [markdown]
# ##Ejercicios 1.2
#
# 1. Crear un nuevo cuaderno y llamarle Ejercicios1.2
# 2. Multiplicar 10 con 5 e imprimir el resultado
# 3. Dividir 10 con 2 e imprimir el resultado
# 4. Usar el operador adecuado para verificar si “manzana” está presente en fruta

# %%
#Dividir 10 con 2 e imprimir el resultado
print(10/2)
# Out:
# 5.0

# %%
#Usar el operador adecuado para verificar si “manzana” está presente en fruta
Frutas = ["manzana", "pera"]

if "manzana" in Frutas:
 print ("Correcto, manzana es una fruta!")
# Out:
# Correcto, manzana es una fruta!

# %%
#Usar el operador de comparación adecuado para verificar si 5 no es igual a 10
if 5 != 10:
  print ("5 y 10 no son iguales")
# Out:
# 5 y 10 no son iguales

# %%
#Usar el operador lógico adecuado para verificar si al menos una de las 2 sentencias es True
if 5 | 10:
  print ("5 y 10 no son iguales")
# Out:
# 5 y 10 no son iguales

# %%
#Usar el operador de comparación adecuado para verificar si 5 no es igual a 10
if 5 != 10:
  print ("5 y 10 no son iguales")
# Out:
# 5 y 10 no son iguales

# %%
#Usar el operador lógico adecuado para verificar si al menos una de las 2 sentencias es True
if 5 == 10 | 4 == 4:
  print ("al menos una de lasdos es verdadera")
