# %%
import pandas as pd

# %% [markdown]
# ##Ejercicio:
# Subir el archivo https://www.kaggle.com/sudalairajkumar/covid19-in-italy?select=covid19_italy_region.csv al almacenamiento de sesión

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/CursoPythonAvanzado/BreveRepasoDePython/Datasets/covid19_italy_region.csv"
Covid = pd.read_csv (path);
Covid
# Out:
#        SNo                 Date  ... TotalPositiveCases  TestsPerformed
# 0        0  2020-02-24T18:00:00  ...                  0             NaN
# 1        1  2020-02-24T18:00:00  ...                  0             NaN
# 2        2  2020-02-24T18:00:00  ...                  0             NaN
# 3        3  2020-02-24T18:00:00  ...                  0             NaN
# 4        4  2020-02-24T18:00:00  ...                 18             NaN
# ...    ...                  ...  ...                ...             ...
# 6022  6022  2020-12-06T17:00:00  ...              71489        692062.0
# 6023  6023  2020-12-06T17:00:00  ...             108397        983103.0
# 6024  6024  2020-12-06T17:00:00  ...              25144        231538.0
# 6025  6025  2020-12-06T17:00:00  ...               6726         34644.0
# 6026  6026  2020-12-06T17:00:00  ...             165249       1090932.0
#
# [6027 rows x 17 columns]

# %% [markdown]
# ##Ejercicios
#
# 1. Crear un dataFrame frutas como la siguiente tabla:
#
# .   | Manzanas | Peras
# ---|----------|---------
# 2020 |  35|  21
# 2021 |  42|  34

# %%
datos = [[35, 21],
         [42, 34]]

columnas = ['Manzanas', 'Peras'] 
filas = ['2020', '2021'] 
df = pd.DataFrame(datos, columns=columnas, index=filas)

#Con diccionario
dic = {"Manzanas":[35, 42],"Peras": [21,34]}
df_2 = pd.DataFrame(dic,index=filas)

#otra forma de hacerlo:
df_ = pd.DataFrame ([[35, 21], [42, 34]], columns= ['Manzanas', 'Peras'], index =['2020', '2021'])

print(df_)
print("\n",df)
print("\n", df_2)
# Out:
#       Manzanas  Peras
# 2020        35     21
# 2021        42     34
#
#        Manzanas  Peras
# 2020        35     21
# 2021        42     34
#
#        Manzanas  Peras
# 2020        35     21
# 2021        42     34

# %% [markdown]
# 2. Crear una Serie de ingredientes como la siguiente:
#
# . | .
# ---|-----
# Hariana | 4 tazas
# Leche  | 1 taza
# Huevos | 2 piezas
# Spam   | 1 lata
#
# con nombre pastel.

# %%
dic = {" ":["4 tazas", "1 taza","2 piezas","1 lata" ]}
ind = ["Hariana", "Leche","Huevos","Spam" ] 

pd.DataFrame(dic,index=ind)
# Out:
#
# Hariana   4 tazas
# Leche      1 taza
# Huevos   2 piezas
# Spam       1 lata

# %% [markdown]
# Ejecute el siguiente snippet para crear y desplegar el siguiente DataFrame

# %%
animales = {"Gatos":[12,20],"Perros":[22,19]}
df_Animales = pd.DataFrame(animales, index = ["Año 1", "Año 2"])
df_Animales
# Out:
#        Gatos  Perros
# Año 1     12      22
# Año 2     20      19

# %% [markdown]
# Guarde en disco el DataFrame en un archivo con nombre "gatosYperros.csv"

# %%
path = "/content/drive/MyDrive/CursoPythonAvanzado/BreveRepasoDePython/Datasets/"
NombreArchivo = "Animales_Prueba.csv"
df_Animales.to_csv(path + NombreArchivo)

# %% [markdown]
# *Ejercicio:* Seleccionar la segunda y tercera entrada usando `iloc ()`.

# %%
Covid.iloc [1:3, 0]
# Out:
# 1    1
# 2    2
# Name: SNo, dtype: int64

# %%
Covid.iloc[[1,2]]
# Out:
#    SNo                 Date Country  ...  Deaths TotalPositiveCases  TestsPerformed
# 1    1  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
# 2    2  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
#
# [2 rows x 17 columns]

# %% [markdown]
# *Ejercicio*: Seleccionar la segunda y tercera entrada usando loc ().

# %%
Covid.loc[2:3]['SNo']
# Out:
# 2    2
# 3    3
# Name: SNo, dtype: int64

# %%
Covid.loc[2:3],["SNo"]
# Out:
# (   SNo                 Date Country  ...  Deaths TotalPositiveCases  TestsPerformed
#  2    2  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
#  3    3  2020-02-24T18:00:00     ITA  ...       0                  0             NaN
#
#  [2 rows x 17 columns], ['SNo'])

# %% [markdown]
# ##Ejercicios
#
# Substituya --- por uno o más enunciados para resolver el ejercicio

# %% [markdown]
# 1. Crear un data frame con el siguiente dataset [winemag-data-130k-v2.csv](https://www.kaggle.com/zynicide/wine-reviews)

# %%
from google.colab import files

uploaded = files.upload()

# %%
path = "/content/drive/MyDrive/CursoPythonAvanzado/BreveRepasoDePython/Datasets/winemag.csv"
uploaded = pd.read_csv(path)

# %%
reviews = uploaded

# %%
reviews.head ()
# Out:
#    Unnamed: 0   country  ...         variety               winery
# 0           0     Italy  ...     White Blend              Nicosia
# 1           1  Portugal  ...  Portuguese Red  Quinta dos Avidagos
# 2           2        US  ...      Pinot Gris            Rainstorm
# 3           3        US  ...        Riesling           St. Julian
# 4           4        US  ...      Pinot Noir         Sweet Cheeks
#
# [5 rows x 14 columns]

# %% [markdown]
# 2. Seleccione la columna `description` de `reviews` y asigne el resultado a la variable `desc`.

# %%
desc = reviews["description"]
desc
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
# 2         Tart and snappy, the flavors of lime flesh and...
# 3         Pineapple rind, lemon pith and orange blossom ...
# 4         Much like the regular bottling from 2012, this...
#                                 ...
# 129966    Notes of honeysuckle and cantaloupe sweeten th...
# 129967    Citation is given as much as a decade of bottl...
# 129968    Well-drained gravel soil gives this wine its c...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %% [markdown]
# 3. Seleccione el primer valor de la columna `description` de `reviews` y asígnelo a la variable `primeraDescripción`.

# %%
primeraDescripción = reviews["description"][0]
primeraDescripción

#Usando .loc
primeraDescripción_1 = reviews.loc[0,'description']
primeraDescripción_1

#Usando .iloc
primeraDescripción_2 = reviews.iloc[0,2]
primeraDescripción_2
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %% [markdown]
# 4. Seleccione el primer renglón de `reviews` y asígnelo a la variable `primerRenglón`.

# %%
primerRenglón = reviews.iloc[[0]]
primerRenglón
# Out:
#    Unnamed: 0 country  ...      variety   winery
# 0           0   Italy  ...  White Blend  Nicosia
#
# [1 rows x 14 columns]

# %% [markdown]
# 5. Seleccione los primeros 10 valores de la columna `description` de `review`s, asígnelo a la variable `primerasDescripciones`.

# %%
primerasDescripciones = reviews["description"][0:5]
primerasDescripciones
#Usando .loc
primerasDescripciones_1 = reviews.loc[0:5,'description']
primerasDescripciones_1
#Usando .iloc
primerasDescripciones_2 = reviews.iloc[0:5,[2]]
primerasDescripciones_2
# Out:
#                                          description
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...

# %% [markdown]
# 6. Selecciones con registros con `index labels 1,2,3,5 y 8`, asigne el resultado a la variable `algunasRevisiones`.

# %%
algunasRevisiones = reviews.iloc[[1,2,3,5,8]]
algunasRevisiones
# Out:
#    Unnamed: 0   country  ...             variety               winery
# 1           1  Portugal  ...      Portuguese Red  Quinta dos Avidagos
# 2           2        US  ...          Pinot Gris            Rainstorm
# 3           3        US  ...            Riesling           St. Julian
# 5           5     Spain  ...  Tempranillo-Merlot               Tandem
# 8           8   Germany  ...      Gewürztraminer          Heinz Eifel
#
# [5 rows x 14 columns]

# %% [markdown]
# 7. Crear una variable `df` que contenga las `columnas country, province, region_1 y region_2` y los registros con `index labels 0, 1, 10 y 100`.

# %%
df = reviews.loc[[0,1,10,100],["country", "province", "region_1","region_2"]]
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %% [markdown]
# 8. Crear una variable df que contenga las columnas country y variety de los primeros 100 registros

# %%
df = reviews.loc[0:100,["country", "variety"]]
df
# Out:
#       country                   variety
# 0       Italy               White Blend
# 1    Portugal            Portuguese Red
# 2          US                Pinot Gris
# 3          US                  Riesling
# 4          US                Pinot Noir
# ..        ...                       ...
# 96     France                     Gamay
# 97         US                  Riesling
# 98      Italy                Sangiovese
# 99         US  Bordeaux-style Red Blend
# 100        US                Pinot Gris
#
# [101 rows x 2 columns]

# %% [markdown]
# 9. Crear un dataFrame `italianWines` que contenga las `reviews` de los vinos hechos en `Italy`.

# %%
italianWines = reviews.loc[(reviews.country == 'Italy') ]
italianWines
# Out:
#         Unnamed: 0 country  ...            variety                           winery
# 0                0   Italy  ...        White Blend                          Nicosia
# 6                6   Italy  ...           Frappato                  Terre di Giurfo
# 13              13   Italy  ...  Nerello Mascalese              Masseria Setteporte
# 22              22   Italy  ...        White Blend               Baglio di Pianetto
# 24              24   Italy  ...       Nero d'Avola                        Canicattì
# ...            ...     ...  ...                ...                              ...
# 129929      129929   Italy  ...           Prosecco             Col Vetoraz Spumanti
# 129943      129943   Italy  ...          Red Blend  Baglio del Cristo di Campobello
# 129947      129947   Italy  ...          Red Blend         Feudo Principi di Butera
# 129961      129961   Italy  ...           Frappato                              COS
# 129962      129962   Italy  ...       Nero d'Avola                         Cusumano
#
# [19540 rows x 14 columns]

# %% [markdown]
# 9. Crear un DataFrame `topWinesOceania` con todas las revisiones de los vinos con al menos `95 points` de `Australia` y `New Zealand`.

# %%
topWinesOceania = reviews.loc[((reviews.country=='Australia')|(reviews.country=='New Zealand'))&(reviews.points >= 95)]
topWinesOceania
# Out:
#         Unnamed: 0  ...                       winery
# 345            345  ...  Chambers Rosewood Vineyards
# 346            346  ...  Chambers Rosewood Vineyards
# 348            348  ...  Chambers Rosewood Vineyards
# 349            349  ...                     Torbreck
# 356            356  ...                  Jasper Hill
# 360            360  ...                     Torbreck
# 365            365  ...                    Wakefield
# 14354        14354  ...                      Kaesler
# 16538        16538  ...                      Lambert
# 28573        28573  ...              Clarendon Hills
# 34502        34502  ...                     Standish
# 34506        34506  ...                     Standish
# 38988        38988  ...                     Penfolds
# 39059        39059  ...                    Wakefield
# 39961        39961  ...                     Penfolds
# 39962        39962  ...                     Penfolds
# 45809        45809  ...              Clarendon Hills
# 56953        56953  ...                     Penfolds
# 56956        56956  ...                     Standish
# 56957        56957  ...                 Thorn Clarke
# 56959        56959  ...                     Henschke
# 59977        59977  ...                 Hickinbotham
# 59984        59984  ...                    Heartland
# 67096        67096  ...            R.L. Buller & Son
# 67101        67101  ...  Chambers Rosewood Vineyards
# 76392        76392  ...                  Jasper Hill
# 77028        77028  ...                     Penfolds
# 77036        77036  ...                     Penfolds
# 77037        77037  ...                     Torbreck
# 77042        77042  ...             John Duval Wines
# 77044        77044  ...                   Kilikanoon
# 77046        77046  ...                     Torbreck
# 83357        83357  ...                     Penfolds
# 84815        84815  ...                     Torbreck
# 84816        84816  ...                     Nashwauk
# 87128        87128  ...                 Kay Brothers
# 87137        87137  ...                    Moss Wood
# 87143        87143  ...                    Wakefield
# 91851        91851  ...                 Trinity Hill
# 98386        98386  ...                   D'Arenberg
# 99318        99318  ...                     Henschke
# 99330        99330  ...                     Penfolds
# 99340        99340  ...                     Torbreck
# 109427      109427  ...  Chambers Rosewood Vineyards
# 109434      109434  ...                   D'Arenberg
# 122421      122421  ...                     Glaetzer
# 122430      122430  ...                     Glaetzer
# 122507      122507  ...             Squawking Magpie
# 122939      122939  ...                     Torbreck
#
# [49 rows x 14 columns]

# %% [markdown]
# # **Ejercicios**
#
# Substituya ------ por uno o más enunciados para resolver el ejercicio

# %% [markdown]
# 1. ¿Cuál es la mediana de la columna points en el DataFrame reviews?

# %%
median_points = reviews.points.mean ()
median_points
# Out:
# 88.44713820775404

# %% [markdown]
# 2. ¿Qué países están representados en el dataSet? (La respuesta no debe contener duplicados)

# %%
reviews.country.unique ()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %% [markdown]
# 3. ¿Qué tan frecuente aparece cada país en el dataset? Crear una serie para mapear países con el número de revisiones

# %%
pd.Series(reviews.country.value_counts())
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# Peru                         16
# Ukraine                      14
# Macedonia                    12
# Serbia                       12
# Czech Republic               12
# Cyprus                       11
# India                         9
# Switzerland                   7
# Luxembourg                    6
# Armenia                       2
# Bosnia and Herzegovina        2
# Egypt                         1
# Slovakia                      1
# China                         1
# Name: country, dtype: int64

# %% [markdown]
# 4. Crear una variable centPrecio que contenga una versión de la columna price con la resta del promedio

# %%
reviewsPointsMean = reviews.price.mean ()

reviews.price.map (lambda p: p-reviewsPointsMean)
# Out:
# 0               NaN
# 1        -20.363389
# 2        -21.363389
# 3        -22.363389
# 4         29.636611
#             ...
# 129966    -7.363389
# 129967    39.636611
# 129968    -5.363389
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %% [markdown]
# 5. ¿Qué vino tiene la mejor relación puntos precio en el dataset?<p>
# Nota: puede usar el método idxmax

# %%
#nombre de las columnas
reviews.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
i = (reviews.points/reviews.price).idxmax()
mejorV = i
Relacion = reviews.loc[i,"title"]
Relacion
# Out:
# 'Bandit NV Merlot (California)'

# %% [markdown]
# 6. Cuente cuántas veces se repiten las palabras 'tropical' o 'fruity' en la columna description del dataset.

# %%
t = reviews.description.map (lambda d : 'tropical' in d).sum()
f = reviews.description.map (lambda d : 'fruity'   in d).sum()
cuentas = pd.Series ([t,f], index=['tropical', 'fruity'])
cuentas
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %% [markdown]
# 7. Modificar el sistema de points por una más simple de estrellas. Una calificación de 95 o más puntos tendrá 3 estrellas, uno entre 95 y 85 2 estrellas y el resto 1 estrellas. Además, si el país es Francia tendrá 3 puntos.

# %%
def estrellas (r):
  if (r.country == 'France') |(r.points >= 95): return 3
  if r.points >= 85: return 2
  return 1

estrellasRatings = reviews.apply (estrellas, axis = 'columns')  
estrellasRatings
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 129966    2
# 129967    2
# 129968    3
# 129969    3
# 129970    3
# Length: 129971, dtype: int64

# %%
frecu = estrellasRatings.value_counts()
frecu
# Out:
# 2    95244
# 3    23844
# 1    10883
# dtype: int64
