# %%
import pandas as pd
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt 


path = "/content/drive/MyDrive/Colab Notebooks/"
df = pd.read_csv(path+"iris4.csv")
#Guardar la columna 'class'
y = df['class']
df=df.drop(['class'],axis=1)

#Normalizar
from sklearn.preprocessing import StandardScaler
X_val = np.asarray(df.values)
X_Norm = StandardScaler().fit_transform(X_val)
df_Norm = pd.DataFrame(X_Norm)
# df_Norm.plot.scatter(x=0,y=1)
# df.plot.scatter(x="sepal_length",y="sepal_width")
cov_mat = df_Norm.cov()
valorPropio, vectorPropio = np.linalg.eig(cov_mat)
#verEigValues
print('valorPropio\n',valorPropio)
print('vectorPropio\n',vectorPropio)

var_explicada = []
for i in range(len(eigenvalue)):
    var_explicada.append(valorPropio[i] / np.sum(valorPropio))
print(var_explicada)
# Out:
# valorPropio
#  [2.93035378 0.92740362 0.14834223 0.02074601]
# vectorPropio
#  [[ 0.52237162 -0.37231836 -0.72101681  0.26199559]
#  [-0.26335492 -0.92555649  0.24203288 -0.12413481]
#  [ 0.58125401 -0.02109478  0.14089226 -0.80115427]
#  [ 0.56561105 -0.06541577  0.6338014   0.52354627]]
# [0.7277045209380132, 0.2303052326768066, 0.03683831957627382, 0.005151926808906328]

# %%
import pandas as pd
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt 

path = "/content/drive/MyDrive/Colab Notebooks/"
df = pd.read_csv(path+"iris4.csv")
df=df.drop(['class','sepal_width','petal_width'],axis=1)
from sklearn.preprocessing import StandardScaler
X_val = np.asarray(df.values)
X_Norm = StandardScaler().fit_transform(X_val)
df_Norm = pd.DataFrame(X_Norm)
cov_mat = df_Norm.cov()
valorPropio, vectorPropio = np.linalg.eig(cov_mat)

print('valorPropio\n',valorPropio)
print('vectorPropio\n',vectorPropio)
df_Norm.plot.scatter(x=0,y=1)
# Out:
# valorPropio
#  [1.88431627 0.12910655]
# vectorPropio
#  [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
vectorPropio
# Out:
# array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678]])
