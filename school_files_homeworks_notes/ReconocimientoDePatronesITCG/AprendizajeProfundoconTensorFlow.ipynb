# %% [markdown]
# **Juan José Solórzano Carrillo**

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# # **Aprendizaje Profundo con TensorFlow **

# %%
#Configuración
import numpy as np
import time
import PIL.Image as Image
import matplotlib.pylab as plt
import tensorflow as tf
import tensorflow_hub as hub

#Modelo
classifier_model ="https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4"
#Tamaño de la imagen
IMAGE_SHAPE = (224, 224)
classifier = tf.keras.Sequential([hub.KerasLayer(classifier_model, input_shape=IMAGE_SHAPE+(3,))])

# %%
#Conjunto de datos Cats
Cats = '/content/drive/MyDrive/Colab Notebooks/Cats1'
batch_size = 50
img_height = 224
img_width = 224
#Se cargan los datos al modelo pre-entrenado
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  str(Cats),
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 348 files belonging to 6 classes.
# Using 279 files for training.

# %%
#Se obtienen las diferentes clases de razas de gatos (sólo se toman 5 tipos de razas)
class_names = np.array(train_ds.class_names)
print(class_names)
#Normalización de los datos
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# ['Abyssinian' 'Bengal' 'Manx' 'Persian' 'Siamese' 'Tiger']

# %%
#Normalización
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
#labels_path ='/content/drive/MyDrive/Colab Notebooks/Cats1/DataCats.txt'
imagenet_labels = np.array(open(labels_path).read().splitlines())
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt
# 16384/10484 [==============================================] - 0s 0us/step

# %%
#
for Cats1, labels_batch in train_ds:
  print(Cats1.shape)
  print(labels_batch.shape)
  break

#Se entrena el modelo 
result_batch = classifier.predict(train_ds)
predicted_class_names = imagenet_labels[np.argmax(result_batch, axis=-1)]
predicted_class_names
# Out:
# (50, 224, 224, 3)
# (50,)
# array(['sleeping bag', 'tabby', 'Egyptian cat', 'Egyptian cat',
#        'malinois', 'Persian cat', 'Siamese cat', 'Egyptian cat',
#        'mongoose', 'Shih-Tzu', 'Egyptian cat', 'Persian cat',
#        'Persian cat', 'Egyptian cat', 'tiger cat', 'tabby', 'chest',
#        'Egyptian cat', 'Persian cat', 'bath towel', 'Persian cat',
#        'tabby', 'grocery store', 'tabby', 'Egyptian cat', 'Egyptian cat',
#        'Persian cat', 'Siamese cat', 'Siamese cat', 'Egyptian cat',
#        'Egyptian cat', 'Siamese cat', 'Persian cat', 'tiger cat', 'tabby',
#        'Egyptian cat', 'Angora', 'Angora', 'tabby', 'Egyptian cat',
#        'Egyptian cat', 'Egyptian cat', 'Persian cat', 'Egyptian cat',
#        'Egyptian cat', 'Egyptian cat', 'tabby', 'tiger cat', 'tiger cat',
#        'Persian cat', 'Egyptian cat', 'Persian cat', 'Siamese cat',
#        'tiger cat', 'Egyptian cat', 'lynx', 'Egyptian cat',
#        'Egyptian cat', 'tabby', 'Egyptian cat', 'Egyptian cat',
#        'Persian cat', 'Egyptian cat', 'Egyptian cat', 'tabby', 'tabby',
#        'Egyptian cat', 'Egyptian cat', 'Egyptian cat', 'Egyptian cat',
#        'Egyptian cat', 'Siamese cat', 'schipperke', 'Egyptian cat',
#        'tabby', 'Persian cat', 'Persian cat', 'Egyptian cat',
#        'Siamese cat', 'Egyptian cat', 'Egyptian cat', 'Egyptian cat',
#        'Egyptian cat', 'Egyptian cat', 'Persian cat', 'tabby',
#        'tiger cat', 'Egyptian cat', 'Chihuahua', 'tabby', 'tabby',
#        'Egyptian cat', 'Persian cat', 'lynx', 'tabby', 'Persian cat',
#        'tabby', 'Siamese cat', 'Egyptian cat', 'tabby', 'Samoyed',
#        'black-footed ferret', 'Persian cat', 'tabby', 'tabby',
#        'Persian cat', 'Siamese cat', 'Persian cat', 'tabby', 'tabby',
#        'tabby', 'Arctic fox', 'lynx', 'Egyptian cat', 'tabby', 'Angora',
#        'Siamese cat', 'Siamese cat', 'Persian cat', 'lynx', 'Siamese cat',
#        'Siamese cat', 'Siamese cat', 'Persian cat', 'Siamese cat',
#        'Egyptian cat', 'Siamese cat', 'Egyptian cat', 'Persian cat',
#        'tabby', 'Egyptian cat', 'Siamese cat', 'Persian cat',
#        'Persian cat', 'Persian cat', 'digital clock', 'toilet seat',
#        'Persian cat', 'Persian cat', 'tabby', 'Egyptian cat',
#        'Eskimo dog', 'tabby', 'tabby', 'Siamese cat', 'Egyptian cat',
#        'tabby', 'Persian cat', 'Egyptian cat', 'Egyptian cat', 'tabby',
#        'Persian cat', 'Persian cat', 'tabby', 'tabby', 'Egyptian cat',
#        'Siamese cat', 'Egyptian cat', 'tabby', 'Siamese cat',
#        'Egyptian cat', 'Siamese cat', 'Persian cat', 'grey fox', 'tabby',
#        'Egyptian cat', 'Egyptian cat', 'Siamese cat', 'lynx',
#        'Egyptian cat', 'Egyptian cat', 'lynx', 'Egyptian cat', 'tabby',
#        'Persian cat', 'titi', 'tabby', 'tabby', 'Persian cat',
#        'Egyptian cat', 'tiger cat', 'Egyptian cat', 'Persian cat',
#        'Persian cat', 'Egyptian cat', 'window screen', 'Egyptian cat',
#        'tabby', 'Persian cat', 'Egyptian cat', 'tabby',
#        'Shetland sheepdog', 'tabby', 'tabby', 'papillon', 'Egyptian cat',
#        'Egyptian cat', 'Egyptian cat', 'Persian cat', 'Egyptian cat',
#        'tabby', 'tabby', 'Siamese cat', 'Siamese cat', 'tabby',
#        'mongoose', 'tabby', 'Siamese cat', 'keeshond', 'tabby',
#        'Persian cat', 'Siamese cat', 'coyote', 'Persian cat',
#        'Siamese cat', 'Persian cat', 'Egyptian cat', 'Egyptian cat',
#        'Egyptian cat', 'tabby', 'Egyptian cat', 'Egyptian cat',
#        'Egyptian cat', 'toy terrier', 'toilet seat', 'Egyptian cat',
#        'Egyptian cat', 'tabby', 'Egyptian cat', 'Egyptian cat',
#        'schipperke', 'Egyptian cat', 'Persian cat', 'Siamese cat',
#        'Egyptian cat', 'tabby', 'papillon', 'tabby', 'tabby',
#        'Persian cat', 'Egyptian cat', 'tabby', 'Siamese cat', 'tiger cat',
#        'Siamese cat', 'tabby', 'Siamese cat', 'Egyptian cat',
#        'Egyptian cat', 'lynx', 'Egyptian cat', 'Egyptian cat',
#        'Egyptian cat', 'tabby', 'red fox', 'Persian cat', 'tabby',
#        'Egyptian cat', 'cairn', 'Persian cat', 'tabby', 'Siamese cat',
#        'Egyptian cat', 'Siamese cat', 'Egyptian cat', 'Egyptian cat',
#        'tabby', 'tabby', 'Egyptian cat', 'Persian cat', 'tiger cat',
#        'Persian cat', 'Egyptian cat', 'tabby', 'Egyptian cat',
#        'Egyptian cat', 'Egyptian cat', 'Persian cat', 'Persian cat'],
#       dtype='<U30')

# %%
#Se grafican los resultados
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)

for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(Cats1[n])
  plt.title(predicted_class_names[n])
  plt.axis('off')


#Los resultados no son del todo buenos, pero tomando en cuanta que el modelo no se entreno para estos datos, sí acierta en algunos casos.
_ = plt.suptitle("ImageNet predictions")

# %%
#Volvemos a cargar el modelo
feature_extractor_model = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

# %%
#Se entrena solo la capa del clasificador
feature_extractor_layer = hub.KerasLayer(
    feature_extractor_model, input_shape=(224, 224, 3), trainable=False)

# %%
#Devuelve un vector de 1280 de longitud para cada imagen
feature_batch = feature_extractor_layer(Cats1)
print(feature_batch.shape)
# Out:
# (50, 1280)

# %%
#Etiquetas encontradas
class_names
# Out:
# array(['Abyssinian', 'Bengal', 'Manx', 'Persian', 'Siamese', 'Tiger'],
#       dtype='<U10')

# %%
#Se agregan las etiquetas de clasificación al modelo
num_classes = len(class_names)

model = tf.keras.Sequential([
  feature_extractor_layer,
  tf.keras.layers.Dense(num_classes)
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_2 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 6)                 7686
# =================================================================
# Total params: 2,265,670
# Trainable params: 7,686
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
#Volvemos a pasar el conjunto de datos Cats1
predictions = model(Cats1)
predictions.shape
# Out:
# TensorShape([50, 6])

# %% [markdown]
# # **Resultados con: epochs=2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Mala predicción**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Se entrena el modelo 
model.compile(
  optimizer=tf.keras.optimizers.Adam(),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])
class CollectBatchStats(tf.keras.callbacks.Callback):
  def __init__(self):
    self.batch_losses = []
    self.batch_acc = []

  def on_train_batch_end(self, batch, logs=None):
    self.batch_losses.append(logs['loss'])
    self.batch_acc.append(logs['acc'])
    self.model.reset_metrics()

batch_stats_callback = CollectBatchStats()

history = model.fit(train_ds, epochs=12,callbacks=[batch_stats_callback])
# Out:
# Epoch 1/12
# 6/6 [==============================] - 10s 1s/step - loss: 1.7248 - acc: 0.2759
# Epoch 2/12
# 6/6 [==============================] - 7s 1s/step - loss: 1.3097 - acc: 0.5172
# Epoch 3/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.9860 - acc: 0.7586
# Epoch 4/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.8560 - acc: 0.7931
# Epoch 5/12
# 6/6 [==============================] - 6s 1s/step - loss: 0.7571 - acc: 0.7586
# Epoch 6/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.6522 - acc: 0.7931
# Epoch 7/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.5759 - acc: 0.8966
# Epoch 8/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.5240 - acc: 0.8966
# Epoch 9/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.4761 - acc: 0.9310
# Epoch 10/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.4316 - acc: 0.9310
# Epoch 11/12
# 6/6 [==============================] - 6s 1s/step - loss: 0.3958 - acc: 0.9655
# Epoch 12/12
# 6/6 [==============================] - 7s 1s/step - loss: 0.3661 - acc: 0.9655

# %%
#Se observa como el modelo mejora al aumentar los épocas
plt.figure()
plt.ylabel("Loss")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(batch_stats_callback.batch_losses)

# %%
#Amunta la precisión 
plt.figure()
plt.ylabel("Accuracy")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(batch_stats_callback.batch_acc)

# %%
Imagen = '/content/drive/MyDrive/Colab Notebooks/Perro1.jpg'
Gato = Image.open(Imagen).resize(IMAGE_SHAPE)

#Tamaño
Gato = np.array(Gato)/255.0

predicted_batch = model.predict(Gato[np.newaxis, ...])
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]

plt.imshow(Gato)
plt.axis('off')
predicted_class_name = predicted_label_batch[0]
_ = plt.title("Prediction: " + predicted_class_name.title())

# %%
Imagen = '/content/drive/MyDrive/Colab Notebooks/GatosTest/Gato3.jpg'
Gato = Image.open(Imagen).resize(IMAGE_SHAPE)

#Tamaño
Gato = np.array(Gato)/255.0

predicted_batch = model.predict(Gato[np.newaxis, ...])
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]

plt.imshow(Gato)
plt.axis('off')
predicted_class_name = predicted_label_batch[0]
_ = plt.title("Prediction: " + predicted_class_name.title())

# %%
Imagen = '/content/drive/MyDrive/Colab Notebooks/GatosTest/Gato4.jpg'
Gato = Image.open(Imagen).resize(IMAGE_SHAPE)

#Tamaño
Gato = np.array(Gato)/255.0

predicted_batch = model.predict(Gato[np.newaxis, ...])
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]

plt.imshow(Gato)
plt.axis('off')
predicted_class_name = predicted_label_batch[0]
_ = plt.title("Prediction: " + predicted_class_name.title())

# %%
Imagen = '/content/drive/MyDrive/Colab Notebooks/GatosTest/Gato5.jpg'
Gato = Image.open(Imagen).resize(IMAGE_SHAPE)

#Tamaño
Gato = np.array(Gato)/255.0

predicted_batch = model.predict(Gato[np.newaxis, ...])
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]

plt.imshow(Gato)
plt.axis('off')
predicted_class_name = predicted_label_batch[0]
_ = plt.title("Prediction: " + predicted_class_name.title())
