# %%
import numpy as np
import time

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub



classifier_model ="https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4"
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer(classifier_model, input_shape=IMAGE_SHAPE+(3,))
])

# %%
Imagen = '/content/drive/MyDrive/Colab Notebooks/Image.jpg'
Imagen2 = '/content/drive/MyDrive/Colab Notebooks/Flor1.jpg'
Imagen3 = '/content/drive/MyDrive/Colab Notebooks/Gato.jpg'
#https://www.kaggle.com/crawford/cat-dataset
grace_hopper = tf.keras.utils.get_file('image.jpg','https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg')
grace_hopper = Image.open(grace_hopper).resize(IMAGE_SHAPE)
grace_hopper
#Tamaño
grace_hopper = np.array(grace_hopper)/255.0
grace_hopper.shape

result = classifier.predict(grace_hopper[np.newaxis, ...])
result.shape
predicted_class = np.argmax(result[0], axis=-1)
predicted_class

#Etiquetas 
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())

plt.imshow(grace_hopper)
plt.axis('off')
predicted_class_name = imagenet_labels[predicted_class]
_ = plt.title("Prediction: " + predicted_class_name.title())
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg
# 65536/61306 [================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt
# 16384/10484 [==============================================] - 0s 0us/step

# %%
predicted_class
# Out:
# 653

# %%
data_root1 = '/content/drive/MyDrive/Colab Notebooks/flower_photos'



train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  str(data_root1),
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1206 files belonging to 5 classes.
# Using 965 files for training.

# %%
class_names = np.array(train_ds.class_names)
print(class_names)
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-4712f353f212> in <module>()
# ----> 1 class_names = np.array(train_ds.class_names)
#       2 print(class_names)
#       3 normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
#       4 train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
#
# AttributeError: 'MapDataset' object has no attribute 'class_names'

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
result_batch = classifier.predict(train_ds)
predicted_class_names = imagenet_labels[np.argmax(result_batch, axis=-1)]
predicted_class_names
# Out:
# (32, 224, 224, 3)
# (32,)
# array(['bee', 'sea anemone', 'daisy', 'daisy', 'daisy', 'daisy',
#        'volcano', 'bee', 'daisy', 'quill', 'bubble', 'cardoon',
#        'sea urchin', 'plow', 'daisy', 'daisy', 'daisy', 'lakeside',
#        'daisy', 'daisy', 'bee', 'daisy', 'sea urchin', 'daisy', 'daisy',
#        'daisy', 'barn spider', 'daisy', 'pot', 'daisy', 'lacewing',
#        'daisy', 'bee', 'sea urchin', 'daisy', 'daisy', 'daisy', 'daisy',
#        'cardoon', 'daisy', 'mushroom', 'sulphur-crested cockatoo',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy',
#        'barn spider', 'daisy', 'cardoon', 'daisy', 'cardoon', 'bee',
#        'sea urchin', 'daisy', 'daisy', 'daisy', 'daisy', 'bee', 'bee',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy',
#        'puffer', 'sea urchin', 'daisy', 'ant', 'daisy', 'barn spider',
#        'daisy', 'daisy', 'sea urchin', 'cardoon', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'bee', 'rapeseed', 'hay',
#        'tiger beetle', 'bee', 'daisy', 'daisy', 'daisy', 'feather boa',
#        'cardoon', 'daisy', 'daisy', 'cardoon', 'daisy', 'daisy', 'tripod',
#        'daisy', 'barn spider', 'daisy', 'quill', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'spider web', 'daisy', 'daisy', 'daisy',
#        'daisy', 'cardoon', 'daisy', 'daisy', 'buckeye', 'daisy', 'daisy',
#        'daisy', 'hip', 'daisy', 'daisy', 'sulphur-crested cockatoo',
#        'daisy', 'daisy', 'daisy', 'sea urchin', 'wool', 'cardoon',
#        'daisy', 'daisy', 'daisy', 'tick', 'daisy', 'sea urchin',
#        'cardoon', 'daisy', 'daisy', 'daisy', 'daisy', 'broom',
#        'lampshade', 'daisy', 'fly', 'daisy', 'cardoon', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'cardoon',
#        'sea anemone', 'daisy', 'daisy', 'African grey', 'buckeye',
#        'lacewing', 'daisy', 'daisy', 'cardoon', 'cardoon', 'cardoon',
#        'cardoon', 'sea urchin', 'daisy', 'daisy', 'quill', 'daisy',
#        'daisy', 'daisy', 'daisy', 'mushroom', 'daisy', 'ringlet', 'daisy',
#        'daisy', 'daisy', 'cardoon', 'daisy', 'ant', 'daisy', 'daisy',
#        'vine snake', 'daisy', 'daisy', 'daisy', 'daisy', 'broom', 'daisy',
#        'mushroom', 'daisy', 'porcupine', 'handkerchief', 'fly', 'cardoon',
#        'daisy', 'mushroom', 'mushroom', 'daisy', 'mushroom', 'cardoon',
#        'fly', 'hair slide', 'rapeseed', 'daisy', 'vase', 'cardoon',
#        'daisy', 'jellyfish', 'daisy', 'daisy', 'rapeseed', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'grasshopper',
#        'cardoon', 'daisy', 'sea urchin', 'mousetrap', 'spider web',
#        'daisy', 'daisy', 'cardoon', 'daisy', 'quill', 'daisy', 'daisy',
#        'daisy', 'daisy', 'sea urchin', 'chime', 'mushroom', 'tripod',
#        'daisy', 'fountain', 'daisy', 'daisy', 'hip', 'daisy',
#        'Persian cat', 'daisy', 'daisy', 'lycaenid', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'Bedlington terrier', 'daisy', 'daisy',
#        'broccoli', 'daisy', 'daisy', 'bee', 'daisy', 'tarantula', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'swab',
#        'volcano', 'cardoon', 'daisy', 'quill', 'daisy', 'daisy', 'daisy',
#        'daisy', 'porcupine', 'hip', 'daisy', 'daisy', 'daisy', 'daisy',
#        'daisy', 'daisy', 'shower curtain', 'mushroom', 'tick', 'daisy',
#        'daisy', 'daisy', 'crane', 'daisy', 'fly', 'daisy', 'porcupine',
#        'daisy', 'daisy', 'quill', 'bee', 'daisy', 'bee', 'sea urchin',
#        'daisy', 'Bedlington terrier', 'barn spider', 'barn spider',
#        'broom', 'daisy', 'cardoon', 'gasmask', 'daisy', 'daisy',
#        'cardoon', 'Bedlington terrier', 'daisy', 'earthstar', 'daisy',
#        'ostrich', 'daisy', 'daisy', 'daisy', 'daisy', 'hay', 'daisy',
#        'daisy', 'sea urchin', 'daisy', 'sea urchin', 'daisy', 'cardoon',
#        'barn spider', 'cucumber', 'ladybug', 'daisy', 'daisy', 'daisy',
#        'daisy', 'bee', 'daisy', 'spider web', 'daisy', 'daisy', 'obelisk',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'cardoon', 'daisy',
#        'daisy', 'cabbage butterfly', 'coral fungus', 'volcano',
#        'Persian cat', 'daisy', 'orange', 'daisy', 'cardoon', 'daisy',
#        'cardoon', 'cardoon', 'daisy', 'daisy', 'mushroom', 'cardoon',
#        'daisy', 'bee', 'cardoon', 'daisy', 'daisy', 'daisy', 'daisy',
#        'daisy', 'daisy', 'buckeye', 'knot', 'daisy', 'cardoon', 'cardoon',
#        'cardoon', 'cardoon', 'daisy', 'daisy', 'mushroom', 'greenhouse',
#        'daisy', 'daisy', 'daisy', 'cardoon', 'daisy', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'fly', 'sea urchin',
#        'sea urchin', 'bee', 'sea urchin', 'cardoon', 'ant', 'sea anemone',
#        'daisy', 'barn spider', 'daisy', 'ant', 'bell cote', 'fountain',
#        'green snake', 'Bedlington terrier', 'ant', 'daisy', 'torch',
#        'daisy', 'sea urchin', 'sea urchin', 'Bedlington terrier', 'daisy',
#        'daisy', 'daisy', 'quill', 'daisy', 'porcupine', 'daisy',
#        'porcupine', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy',
#        'bee', 'peacock', 'daisy', 'daisy', 'mushroom', 'daisy', 'daisy',
#        'daisy', 'daisy', 'sea urchin', 'sea urchin', 'daisy',
#        'feather boa', 'cardoon', 'bee', 'daisy', 'daisy', 'cardoon',
#        'spider web', 'cardoon', 'sea urchin', 'cardoon',
#        'Bedlington terrier', 'nail', 'rocking chair', 'daisy', 'cardoon',
#        'paintbrush', 'daisy', 'daisy', 'bee', 'daisy', 'coral fungus',
#        'mobile home', 'daisy', 'daisy', 'hip', 'daisy', 'daisy',
#        'picket fence', 'broom', 'wool', 'daisy', 'daisy', 'sea urchin',
#        'sea urchin', 'ear', 'daisy', 'buckeye', 'bee', 'daisy', 'daisy',
#        'bee', 'daisy', 'daisy', 'bee', 'daisy', 'daisy', 'daisy',
#        'buckeye', 'daisy', 'bee', 'sea urchin', 'daisy', 'feather boa',
#        'vase', 'quill', 'daisy', 'daisy', 'cardoon', 'daisy', 'daisy',
#        'mushroom', 'daisy', 'daisy', 'daisy', 'sea urchin', 'daisy',
#        'daisy', 'daisy', 'ringlet', 'cardoon', 'feather boa', 'daisy',
#        'bubble', 'daisy', 'jellyfish', 'daisy', 'daisy', 'bee', 'quill',
#        'daisy', 'cardoon', 'lemon', 'hip', 'daisy', 'tarantula', 'daisy',
#        'bee', 'American egret', 'daisy', 'Bedlington terrier', 'daisy',
#        'rapeseed', 'cloak', 'daisy', 'cardoon', 'viaduct', 'bubble',
#        'bee', 'daisy', 'daisy', 'daisy', 'worm fence', 'daisy',
#        'spider web', 'daisy', 'bee', 'daisy', 'bee', 'daisy', 'daisy',
#        'chow', 'sea urchin', 'daisy', 'daisy', 'daisy', 'barn spider',
#        'daisy', 'porcupine', 'daisy', 'daisy', 'porcupine', 'daisy',
#        'cardoon', 'daisy', 'daisy', 'daisy', 'quill', 'daisy', 'daisy',
#        'wool', 'daisy', 'cardoon', 'bee', 'bee', 'daisy', 'cardoon',
#        'daisy', 'daisy', 'sea urchin', 'cardoon', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'maze',
#        'daisy', 'daisy', 'daisy', 'sea urchin', 'daisy', 'daisy',
#        'spotlight', 'daisy', 'cardoon', 'daisy', 'sea urchin',
#        'sea urchin', 'daisy', 'bubble', 'cardoon', 'fly', 'mushroom',
#        'Bedlington terrier', 'Bedlington terrier', 'quill', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'sea urchin', 'daisy',
#        'cardoon', 'daisy', 'cardoon', 'daisy', 'buckeye', 'daisy',
#        'daisy', 'daisy', 'daisy', 'cardoon', 'cardoon', 'stole', 'daisy',
#        'cardoon', 'daisy', 'cardoon', 'porcupine', 'admiral', 'daisy',
#        'cardoon', 'Bedlington terrier', 'bee', 'daisy', 'acorn', 'bee',
#        'hamper', 'daisy', 'earthstar', 'daisy', 'garden spider',
#        'jellyfish', 'daisy', 'coral fungus', 'daisy', 'daisy', 'daisy',
#        'daisy', 'bee', 'bee', 'matchstick', 'cardoon', 'quill', 'daisy',
#        'sea urchin', 'daisy', 'feather boa', 'red-backed sandpiper',
#        'daisy', 'golf ball', 'jigsaw puzzle', 'cardoon', 'daisy', 'daisy',
#        'daisy', 'daisy', 'cardoon', 'daisy', 'daisy', 'daisy', 'daisy',
#        'daisy', 'fly', 'pickelhaube', 'vase', 'cardoon', 'daisy',
#        'Bedlington terrier', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy',
#        'daisy', 'Bedlington terrier', 'daisy', 'daisy', 'daisy', 'daisy',
#        'daisy', 'acorn', 'daisy', 'Bedlington terrier', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'lycaenid', 'daisy',
#        'sea urchin', 'cardoon', 'sea urchin', 'grasshopper', 'reel',
#        'daisy', 'grasshopper', 'sea urchin', 'doormat', 'daisy', 'daisy',
#        'quill', 'daisy', 'feather boa', 'daisy', 'vulture', 'cardoon',
#        'daisy', 'cardoon', 'vase', 'daisy', 'cardoon', 'swab', 'cardoon',
#        'sea urchin', 'ostrich', 'daisy', 'daisy', 'daisy', 'pinwheel',
#        'safety pin', 'daisy', 'daisy', 'daisy', 'green lizard', 'ostrich',
#        'cardoon', 'feather boa', 'daisy', 'daisy', 'daisy', 'sea urchin',
#        'bee', 'sea urchin', 'daisy', 'Border collie', 'ant',
#        'coral fungus', 'mushroom', 'slug', 'daisy', 'daisy', 'daisy',
#        'daisy', 'daisy', 'spider web', 'daisy', 'ear', 'Persian cat',
#        'daisy', 'sea urchin', "yellow lady's slipper", 'golf ball',
#        'cardoon', 'running shoe', 'ant', 'cardoon', 'daisy', 'sea urchin',
#        'mushroom', 'daisy', 'daisy', 'pole', 'daisy', 'sea urchin',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'bee', 'daisy',
#        'daisy', 'sea urchin', 'fountain', 'daisy', 'daisy', 'sea anemone',
#        'daisy', 'torch', 'daisy', 'daisy', 'sea anemone', 'porcupine',
#        'daisy', 'bee', 'bee', 'bee', 'bee', 'porcupine', 'feather boa',
#        'quill', 'daisy', 'daisy', 'barn spider', 'Persian cat',
#        'Bedlington terrier', 'quill', 'cardoon', 'daisy', 'cardoon',
#        'daisy', 'daisy', 'daisy', 'daisy', 'plastic bag', 'daisy',
#        'bubble', 'daisy', 'ladybug', 'sea urchin', 'daisy', 'daisy',
#        'daisy', 'wool', 'bee', 'daisy', 'daisy', 'Bedlington terrier',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy',
#        'sulphur-crested cockatoo', 'daisy', 'daisy', 'cardoon', 'daisy',
#        'daisy', 'daisy', 'leaf beetle', 'cardoon', 'daisy', 'bee',
#        'sulphur butterfly', 'lycaenid', 'daisy', 'daisy', 'coral fungus',
#        'sea urchin', 'spindle', 'cardoon', 'cardoon', 'daisy', 'daisy',
#        'daisy', 'daisy', 'birdhouse', 'Irish terrier', 'matchstick',
#        'daisy', 'daisy', 'sea anemone', 'cardoon', 'daisy', 'rapeseed',
#        'daisy', 'cardoon', 'daisy', 'daisy', 'daisy', 'daisy',
#        'spotlight', 'bald eagle', 'daisy', 'daisy', 'daisy',
#        'Bedlington terrier', 'sea anemone', 'daisy', 'daisy', 'daisy',
#        'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy', 'daisy',
#        'buckeye', 'ear', 'quill', 'pinwheel', 'daisy', 'fountain',
#        'tarantula', 'daisy', 'porcupine', 'daisy', 'goblet', 'daisy',
#        'daisy', 'daisy', 'sea urchin', 'daisy', 'daisy', 'cardoon',
#        'daisy', 'daisy', 'daisy', 'daisy', 'cardoon', 'daisy', 'daisy',
#        'rapeseed', 'daisy', 'quill', 'daisy', 'barn spider', 'tarantula',
#        'daisy', 'daisy', 'hay', 'sea urchin', 'earthstar', 'cardoon',
#        'daisy', 'daisy', 'daisy', 'sea urchin', 'Bedlington terrier',
#        'ear', 'daisy', 'porcupine', 'daisy', 'daisy', 'daisy', 'daisy',
#        'cardoon', 'daisy', 'cardoon', 'daisy', 'cardoon', 'daisy',
#        'feather boa'], dtype='<U30')

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)

for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(predicted_class_names[n])
  plt.axis('off')


_ = plt.suptitle("ImageNet predictions")
